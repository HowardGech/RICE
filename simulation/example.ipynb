# %%
import os
os.chdir('/home/gech/perturb/RICE/simulation')
# the arguments are: num_cells, num_genes, num_causal_effects, graph_type, perturbation_type, seed
# !python gen_simulation.py 10000 100 500 ER soft 1

# %%
# !python run_simulation.py 10000 100 500 ER soft 1
# Out:
# reg=expm, ρ=1.00e+02, α=4.37e+00, h=6.35e-03: 100%|█| 100/100 [03:09<00:00,  1.9
# Change point detected at index: [475, 10000]
# /home/gech/perturb/RICE/simulation/run_simulation.py:177: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame({'measure': m, 'value': acc[m]},index=[0])], ignore_index=True)

# %%
import pandas as pd
results = pd.read_csv('data/n10k_p100_s500_ER_job1_result.csv')
results
# Out:
#             measure       value
# 0         precision    0.978947
# 1            recall    0.930000
# 2                f1    0.953846
# 3               mcc    0.951828
# 4               fdr    0.021053
# 5               fnr    0.070000
# 6                lf    6.302856
# 7                l1    3.972755
# 8                l2    1.983316
# 9                ln   41.299583
# 10             linf    4.683767
# 11              shd   43.000000
# 12              auc    0.992876
# 13             time  189.907722
# 14  peak_gpu_mem_mb  562.000000
